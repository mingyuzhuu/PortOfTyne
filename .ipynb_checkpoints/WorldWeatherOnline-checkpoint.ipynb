# %%
import pandas as pd
import json
import urllib as u
import datetime

# %%
#create APL link 
domain='https://services.marinetraffic.com/api/portcalls/v:4'
origValue = {'q':'Jarrow','date':'2020-01-01','enddate':'2020-01-02','tp':'6','format':'json','key':'2428c01539614ee9bd6142524221802'}
key = '2428c01539614ee9bd6142524221802'

# %%
#create APL link 
domain='https://services.marinetraffic.com/api/portcalls/v:4/8521c2e6e2a9a70eded303bc092f4e2943dd2e64'
origValue = {'APIKEY'

# %%
qprams = u.parse.urlencode(origValue)

# %%
qprams
# Out:
# 'q=Jarrow&date=2020-01-01&enddate=2020-01-02&tp=6&format=json&key=2428c01539614ee9bd6142524221802'

# %%
url = domain +'?' + qprams

# %%
url
# Out:
# 'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=South%2BShields&date=2020-01-01&enddate=2020-01-02&tp=6&format=json&key=2428c01539614ee9bd6142524221802'

# %%
a = pd.DataFrame(json.loads(u.request.urlopen(url).read()))

# %%
a.to_csv('save.csv')

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, request to weather
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    2 non-null      object
# dtypes: object(1)
# memory usage: 32.0+ bytes

# %%
a
# Out:
#                                                       data
# request  [{'type': 'City', 'query': 'South Shields, Uni...
# weather  [{'date': '2020-01-01', 'astronomy': [{'sunris...

# %%
a['data']
# Out:
# request    [{'type': 'City', 'query': 'South Shields, Uni...
# weather    [{'date': '2020-01-01', 'astronomy': [{'sunris...
# Name: data, dtype: object

# %%
b = pd.DataFrame(a['data']['weather'])

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2 non-null      object
#  1   astronomy     2 non-null      object
#  2   maxtempC      2 non-null      object
#  3   maxtempF      2 non-null      object
#  4   mintempC      2 non-null      object
#  5   mintempF      2 non-null      object
#  6   avgtempC      2 non-null      object
#  7   avgtempF      2 non-null      object
#  8   totalSnow_cm  2 non-null      object
#  9   sunHour       2 non-null      object
#  10  uvIndex       2 non-null      object
#  11  hourly        2 non-null      object
# dtypes: object(12)
# memory usage: 320.0+ bytes

# %%
b
# Out:
#          date                                          astronomy maxtempC  \
# 0  2020-01-01  [{'sunrise': '08:30 AM', 'sunset': '03:48 PM',...        6
# 1  2020-01-02  [{'sunrise': '08:30 AM', 'sunset': '03:49 PM',...        9
#
#   maxtempF mintempC mintempF avgtempC avgtempF totalSnow_cm sunHour uvIndex  \
# 0       43        2       35        5       41          0.0     6.7       3
# 1       48        1       33        7       45          0.0     7.2       3
#
#                                               hourly
# 0  [{'time': '0', 'tempC': '5', 'tempF': '41', 'w...
# 1  [{'time': '0', 'tempC': '4', 'tempF': '39', 'w...

# %%
b['date']
# Out:
# 0    2020-01-01
# 1    2020-01-02
# Name: date, dtype: object

# %%
b['hourly']
# Out:
# 0    [{'time': '0', 'tempC': '5', 'tempF': '41', 'w...
# 1    [{'time': '0', 'tempC': '4', 'tempF': '39', 'w...
# Name: hourly, dtype: object

# %%
c = b['hourly'][0]

# %%
pd.DataFrame(pd.DataFrame(a['data']['weather'])['hourly'][0])['windspeedKmph']
# Out:
# 0    22
# 1    15
# 2     9
# 3    17
# Name: windspeedKmph, dtype: object

# %%
pd.DataFrame(pd.DataFrame(a['data']['weather'])['hourly'][0])['humidity']
# Out:
# 0    81
# 1    88
# 2    79
# 3    71
# Name: humidity, dtype: object

# %%
pd.DataFrame(pd.DataFrame(a['data']['weather'])['hourly'][1])['windspeedKmph']
# Out:
# 0    19
# 1    27
# 2    28
# 3    27
# Name: windspeedKmph, dtype: object

# %%
pd.DataFrame(pd.DataFrame(a['data']['weather'])['hourly'][1])['humidity']
# Out:
# 0    86
# 1    81
# 2    67
# 3    82
# Name: humidity, dtype: object

# %%
d = pd.DataFrame(c)

# %%
d.head()
# Out:
#    time tempC tempF windspeedMiles windspeedKmph winddirDegree winddir16Point  \
# 0     0     5    41             14            22           191            SSW
# 1   600     4    40              9            15           195            SSW
# 2  1200     5    41              6             9           225             SW
# 3  1800     6    42             10            17           217             SW
#
#   weatherCode                                     weatherIconUrl  \
# 0         113  [{'value': 'http://cdn.worldweatheronline.com/...
# 1         116  [{'value': 'http://cdn.worldweatheronline.com/...
# 2         122  [{'value': 'http://cdn.worldweatheronline.com/...
# 3         116  [{'value': 'http://cdn.worldweatheronline.com/...
#
#                     weatherDesc  ... HeatIndexF DewPointC DewPointF  \
# 0          [{'value': 'Clear'}]  ...         41         2        35
# 1  [{'value': 'Partly cloudy'}]  ...         40         3        37
# ...

# %%
d['windspeedKmph']
# Out:
# 0    22
# 1    15
# 2     9
# 3    17
# Name: windspeedKmph, dtype: object

# %%
d['humidity']
# Out:
# 0    81
# 1    88
# 2    79
# 3    71
# Name: humidity, dtype: object

# %%
cc = b['hourly'][1]

# %%
pd.DataFrame(cc)['humidity']
# Out:
# 0    86
# 1    81
# 2    67
# 3    82
# Name: humidity, dtype: object

# %% [markdown]
# ### =======================Jan

# %%
testValue1 = {'q':'South+Shields','date':'2020-01-01','enddate':'2020-01-31','tp':'24','format':'json','key':'2428c01539614ee9bd6142524221802'}

# %%
testprams1 = u.parse.urlencode(testValue1)

# %%
testprams1
# Out:
# 'q=South%2BShields&date=2020-01-01&enddate=2020-01-31&tp=24&format=json&key=2428c01539614ee9bd6142524221802'

# %%
testurl1 = domain +'?' + testprams1

# %%
testurl1
# Out:
# 'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=South%2BShields&date=2020-01-01&enddate=2020-01-31&tp=24&format=json&key=2428c01539614ee9bd6142524221802'

# %%
a1 = pd.DataFrame(json.loads(u.request.urlopen(testurl1).read()))

# %%
a1.to_csv('Jan.csv')

# %%
a1['data']
# Out:
# request    [{'type': 'City', 'query': 'South Shields, Uni...
# weather    [{'date': '2020-01-01', 'astronomy': [{'sunris...
# Name: data, dtype: object

# %%
pd.DataFrame(a1['data']['weather'])
# Out:
#           date                                          astronomy maxtempC  \
# 0   2020-01-01  [{'sunrise': '08:30 AM', 'sunset': '03:48 PM',...        6
# 1   2020-01-02  [{'sunrise': '08:30 AM', 'sunset': '03:49 PM',...        9
# 2   2020-01-03  [{'sunrise': '08:30 AM', 'sunset': '03:50 PM',...        6
# 3   2020-01-04  [{'sunrise': '08:30 AM', 'sunset': '03:52 PM',...        9
# 4   2020-01-05  [{'sunrise': '08:29 AM', 'sunset': '03:53 PM',...       10
# 5   2020-01-06  [{'sunrise': '08:29 AM', 'sunset': '03:54 PM',...        9
# 6   2020-01-07  [{'sunrise': '08:28 AM', 'sunset': '03:56 PM',...       10
# 7   2020-01-08  [{'sunrise': '08:28 AM', 'sunset': '03:57 PM',...        7
# 8   2020-01-09  [{'sunrise': '08:27 AM', 'sunset': '03:59 PM',...        7
# 9   2020-01-10  [{'sunrise': '08:26 AM', 'sunset': '04:00 PM',...        6
# 10  2020-01-11  [{'sunrise': '08:25 AM', 'sunset': '04:02 PM',...       12
# ...

# %%
pd.DataFrame(pd.DataFrame(a1['data']['weather'])['hourly'][0])['windspeedKmph']
# Out:
# 0    15
# Name: windspeedKmph, dtype: object

# %%
pd.DataFrame(pd.DataFrame(a1['data']['weather'])['hourly'][0])['humidity']
# Out:
# 0    79
# Name: humidity, dtype: object

# %% [markdown]
# # ======2020 data save to local json

# %%
testValue1 = {'q':'South+Shields','date':'2020-01-01','enddate':'2020-01-31','tp':'24','format':'json','key':'2428c01539614ee9bd6142524221802'}

# %%
testprams1 = u.parse.urlencode(testValue1)
testprams1
# Out:
# 'q=South%2BShields&date=2020-01-01&enddate=2020-01-31&tp=24&format=json&key=2428c01539614ee9bd6142524221802'

# %%
testurl1 = domain +'?' + testprams1
testurl1
# Out:
# 'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=South%2BShields&date=2020-01-01&enddate=2020-01-31&tp=24&format=json&key=2428c01539614ee9bd6142524221802'

# %%
dJan = json.loads(u.request.urlopen(testurl1).read())

# %%
# Writing to sample.json
with open('E:\\20190923 Newcastle-M.Res\\OneDrive - Newcastle University\\21_22_autumn\\211018\\code\\data\\20Jan.json', 'w+') as f:
    json.dump(dJan, f)

# %%
# dMar.to_csv('Mar.csv')

# %%
# pd.DataFrame(dMar['data']['weather'])
# Out:
#           date                                          astronomy maxtempC  \
# 0   2020-03-01  [{'sunrise': '06:55 AM', 'sunset': '05:42 PM',...        6
# 1   2020-03-02  [{'sunrise': '06:52 AM', 'sunset': '05:45 PM',...        6
# 2   2020-03-03  [{'sunrise': '06:50 AM', 'sunset': '05:47 PM',...        7
# 3   2020-03-04  [{'sunrise': '06:47 AM', 'sunset': '05:49 PM',...        7
# 4   2020-03-05  [{'sunrise': '06:45 AM', 'sunset': '05:51 PM',...        6
# 5   2020-03-06  [{'sunrise': '06:42 AM', 'sunset': '05:53 PM',...        7
# 6   2020-03-07  [{'sunrise': '06:40 AM', 'sunset': '05:55 PM',...       11
# 7   2020-03-08  [{'sunrise': '06:37 AM', 'sunset': '05:56 PM',...        9
# 8   2020-03-09  [{'sunrise': '06:35 AM', 'sunset': '05:58 PM',...        9
# 9   2020-03-10  [{'sunrise': '06:32 AM', 'sunset': '06:00 PM',...       11
# 10  2020-03-11  [{'sunrise': '06:30 AM', 'sunset': '06:02 PM',...        9
# ...

# %% [markdown]
# ### =======2018

# %%
testValue = {'q':'Jarrow','date':'2018-01-01','enddate':'2018-01-31','tp':'24','format':'json','key':'2428c01539614ee9bd6142524221802'}
testprams = u.parse.urlencode(testValue)
testurl = domain +'?' + testprams
testurl
# Out:
# 'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Jarrow&date=2018-01-01&enddate=2018-01-31&tp=24&format=json&key=2428c01539614ee9bd6142524221802'

# %%
d = json.loads(u.request.urlopen(testurl).read())

# %%
pd.DataFrame(d['data']['weather'])
# Out:
#           date                                          astronomy maxtempC  \
# 0   2018-01-01  [{'sunrise': '08:30 AM', 'sunset': '03:49 PM',...        7
# 1   2018-01-02  [{'sunrise': '08:30 AM', 'sunset': '03:50 PM',...        7
# 2   2018-01-03  [{'sunrise': '08:30 AM', 'sunset': '03:51 PM',...        8
# 3   2018-01-04  [{'sunrise': '08:29 AM', 'sunset': '03:52 PM',...        7
# 4   2018-01-05  [{'sunrise': '08:29 AM', 'sunset': '03:54 PM',...        5
# 5   2018-01-06  [{'sunrise': '08:29 AM', 'sunset': '03:55 PM',...        7
# 6   2018-01-07  [{'sunrise': '08:28 AM', 'sunset': '03:56 PM',...        5
# 7   2018-01-08  [{'sunrise': '08:27 AM', 'sunset': '03:58 PM',...        6
# 8   2018-01-09  [{'sunrise': '08:27 AM', 'sunset': '03:59 PM',...        5
# 9   2018-01-10  [{'sunrise': '08:26 AM', 'sunset': '04:01 PM',...        6
# 10  2018-01-11  [{'sunrise': '08:25 AM', 'sunset': '04:03 PM',...        7
# ...

# %%
# Writing to sample.json
with open('E:\\20190923 Newcastle-M.Res\\OneDrive - Newcastle University\\21_22_autumn\\211018\\code\\data\\18Jan.json', 'w+') as f:
    json.dump(d, f)

# %% [markdown]
# ### =======2019

# %%
testValue = {'q':'Jarrow','date':'2019-12-01','enddate':'2019-12-31','tp':'24','format':'json','key':'2428c01539614ee9bd6142524221802'}
testprams = u.parse.urlencode(testValue)
testurl = domain +'?' + testprams
testurl
# Out:
# 'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Jarrow&date=2019-12-01&enddate=2019-12-31&tp=24&format=json&key=2428c01539614ee9bd6142524221802'

# %%
d = json.loads(u.request.urlopen(testurl).read())
pd.DataFrame(d['data']['weather'])
# Out:
#           date                                          astronomy maxtempC  \
# 0   2019-12-01  [{'sunrise': '08:06 AM', 'sunset': '03:43 PM',...        4
# 1   2019-12-02  [{'sunrise': '08:08 AM', 'sunset': '03:42 PM',...        7
# 2   2019-12-03  [{'sunrise': '08:09 AM', 'sunset': '03:42 PM',...        7
# 3   2019-12-04  [{'sunrise': '08:11 AM', 'sunset': '03:41 PM',...        9
# 4   2019-12-05  [{'sunrise': '08:12 AM', 'sunset': '03:40 PM',...       11
# 5   2019-12-06  [{'sunrise': '08:14 AM', 'sunset': '03:40 PM',...       12
# 6   2019-12-07  [{'sunrise': '08:15 AM', 'sunset': '03:39 PM',...       10
# 7   2019-12-08  [{'sunrise': '08:16 AM', 'sunset': '03:39 PM',...        9
# 8   2019-12-09  [{'sunrise': '08:17 AM', 'sunset': '03:38 PM',...        8
# 9   2019-12-10  [{'sunrise': '08:19 AM', 'sunset': '03:38 PM',...       12
# 10  2019-12-11  [{'sunrise': '08:20 AM', 'sunset': '03:38 PM',...        7
# ...

# %%
# Writing to sample.json
with open('E:\\20190923 Newcastle-M.Res\\OneDrive - Newcastle University\\21_22_autumn\\211018\\code\\data\\19Dec.json', 'w+') as f:
    json.dump(d, f)

# %% [markdown]
# ### =======2020

# %%
testValue = {'q':'Jarrow','date':'2020-12-01','enddate':'2020-12-31','tp':'24','format':'json','key':'2428c01539614ee9bd6142524221802'}
testprams = u.parse.urlencode(testValue)
testurl = domain +'?' + testprams
testurl
# Out:
# 'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Jarrow&date=2020-12-01&enddate=2020-12-31&tp=24&format=json&key=2428c01539614ee9bd6142524221802'

# %%
d = json.loads(u.request.urlopen(testurl).read())
pd.DataFrame(d['data']['weather'])
# Out:
#           date                                          astronomy maxtempC  \
# 0   2020-12-01  [{'sunrise': '08:07 AM', 'sunset': '03:43 PM',...        6
# 1   2020-12-02  [{'sunrise': '08:09 AM', 'sunset': '03:42 PM',...        8
# 2   2020-12-03  [{'sunrise': '08:10 AM', 'sunset': '03:41 PM',...        4
# 3   2020-12-04  [{'sunrise': '08:12 AM', 'sunset': '03:40 PM',...        6
# 4   2020-12-05  [{'sunrise': '08:13 AM', 'sunset': '03:40 PM',...        8
# 5   2020-12-06  [{'sunrise': '08:15 AM', 'sunset': '03:39 PM',...        7
# 6   2020-12-07  [{'sunrise': '08:16 AM', 'sunset': '03:39 PM',...        6
# 7   2020-12-08  [{'sunrise': '08:17 AM', 'sunset': '03:39 PM',...        6
# 8   2020-12-09  [{'sunrise': '08:18 AM', 'sunset': '03:38 PM',...        7
# 9   2020-12-10  [{'sunrise': '08:20 AM', 'sunset': '03:38 PM',...        6
# 10  2020-12-11  [{'sunrise': '08:21 AM', 'sunset': '03:38 PM',...        8
# ...

# %%
# Writing to sample.json
with open('E:\\20190923 Newcastle-M.Res\\OneDrive - Newcastle University\\21_22_autumn\\211018\\code\\data\\20Dec.json', 'w+') as f:
    json.dump(d, f)

# %% [markdown]
# # ========= Local file

# %%
import os
os.chdir("E:\\20190923 Newcastle-M.Res\\OneDrive - Newcastle University\\21_22_autumn\\211018\\code\\data")
os.getcwd()
# Out:
# 'E:\\20190923 Newcastle-M.Res\\OneDrive - Newcastle University\\21_22_autumn\\211018\\code\\data'

# %%
Jan18 = pd.read_json('18Jan.json')
Feb18 = pd.read_json('18Feb.json')
Mar18 = pd.read_json('18Mar.json')
Apr18 = pd.read_json('18Apr.json')
May18 = pd.read_json('18May.json')
Jun18 = pd.read_json('18Jun.json')
Jul18 = pd.read_json('18Jul.json')
Aug18 = pd.read_json('18Aug.json')
Sep18 = pd.read_json('18Sep.json')
Oct18 = pd.read_json('18Oct.json')
Nov18 = pd.read_json('18Nov.json')
Dec18 = pd.read_json('18Dec.json')

# %%
Jan19 = pd.read_json('19Jan.json')
Feb19 = pd.read_json('19Feb.json')
Mar19 = pd.read_json('19Mar.json')
Apr19 = pd.read_json('19Apr.json')
May19 = pd.read_json('19May.json')
Jun19 = pd.read_json('19Jun.json')
Jul19 = pd.read_json('19Jul.json')
Aug19 = pd.read_json('19Aug.json')
Sep19 = pd.read_json('19Sep.json')
Oct19 = pd.read_json('19Oct.json')
Nov19 = pd.read_json('19Nov.json')
Dec19 = pd.read_json('19Dec.json')

# %%
Jan20 = pd.read_json('20Jan.json')
Feb20 = pd.read_json('20Feb.json')
Mar20 = pd.read_json('20Mar.json')
Apr20 = pd.read_json('20Apr.json')
May20 = pd.read_json('20May.json')
Jun20 = pd.read_json('20Jun.json')
Jul20 = pd.read_json('20Jul.json')
Aug20 = pd.read_json('20Aug.json')
Sep20 = pd.read_json('20Sep.json')
Oct20 = pd.read_json('20Oct.json')
Nov20 = pd.read_json('20Nov.json')
Dec20 = pd.read_json('20Dec.json')

# %% [markdown]
# #### ===== 2018 windspeed

# %%
wslist1 = list()
for i in range (0,31):
    wslist1.append(pd.DataFrame(pd.DataFrame(Jan18['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist2 = list()
for i in range (0,28):
    wslist2.append(pd.DataFrame(pd.DataFrame(Feb18['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist3 = list()
for i in range (0,31):
    wslist3.append(pd.DataFrame(pd.DataFrame(Mar18['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist4 = list()
for i in range (0,30):
    wslist4.append(pd.DataFrame(pd.DataFrame(Apr18['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist5 = list()
for i in range (0,31):
    wslist5.append(pd.DataFrame(pd.DataFrame(May18['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist6 = list()
for i in range (0,30):
    wslist6.append(pd.DataFrame(pd.DataFrame(Jun18['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist7 = list()
for i in range (0,31):
    wslist7.append(pd.DataFrame(pd.DataFrame(Jul18['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist8 = list()
for i in range (0,31):
    wslist8.append(pd.DataFrame(pd.DataFrame(Aug18['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist9 = list()
for i in range (0,30):
    wslist9.append(pd.DataFrame(pd.DataFrame(Sep18['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist10 = list()
for i in range (0,31):
    wslist10.append(pd.DataFrame(pd.DataFrame(Oct18['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist11 = list()
for i in range (0,30):
    wslist11.append(pd.DataFrame(pd.DataFrame(Nov18['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist12 = list()
for i in range (0,31):
    wslist12.append(pd.DataFrame(pd.DataFrame(Dec18['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
ws2018 = wslist1 + wslist2 + wslist3 + wslist4 + wslist5 + wslist6 + wslist7 + wslist8 + wslist9 + wslist10 + wslist11 + wslist12

# %%
len(ws2018)
# Out:
# 365

# %% [markdown]
# #### ======2018humidity

# %%
hulist1 = list()
for i in range (0,31):
    hulist1.append(pd.DataFrame(pd.DataFrame(Jan18['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist2 = list()
for i in range (0,28):
    hulist2.append(pd.DataFrame(pd.DataFrame(Feb18['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist3 = list()
for i in range (0,31):
    hulist3.append(pd.DataFrame(pd.DataFrame(Mar18['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist4 = list()
for i in range (0,30):
    hulist4.append(pd.DataFrame(pd.DataFrame(Apr18['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist5 = list()
for i in range (0,31):
    hulist5.append(pd.DataFrame(pd.DataFrame(May18['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist6 = list()
for i in range (0,30):
    hulist6.append(pd.DataFrame(pd.DataFrame(Jun18['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist7 = list()
for i in range (0,31):
    hulist7.append(pd.DataFrame(pd.DataFrame(Jul18['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist8 = list()
for i in range (0,31):
    hulist8.append(pd.DataFrame(pd.DataFrame(Aug18['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist9 = list()
for i in range (0,30):
    hulist9.append(pd.DataFrame(pd.DataFrame(Sep18['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist10 = list()
for i in range (0,31):
    hulist10.append(pd.DataFrame(pd.DataFrame(Oct18['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist11 = list()
for i in range (0,30):
    hulist11.append(pd.DataFrame(pd.DataFrame(Nov18['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist12 = list()
for i in range (0,31):
    hulist12.append(pd.DataFrame(pd.DataFrame(Dec18['data']['weather'])['hourly'][i])['humidity'])

# %%
hu2018 = hulist1 + hulist2 + hulist3 + hulist4 + hulist5 + hulist6 + hulist7 + hulist8 + hulist9 + hulist10 + hulist11 + hulist12

# %%
len(hu2018)
# Out:
# 365

# %% [markdown]
# #### ======2019windspeed

# %%
wslist1 = list()
for i in range (0,31):
    wslist1.append(pd.DataFrame(pd.DataFrame(Jan19['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist2 = list()
for i in range (0,28):
    wslist2.append(pd.DataFrame(pd.DataFrame(Feb19['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist3 = list()
for i in range (0,31):
    wslist3.append(pd.DataFrame(pd.DataFrame(Mar19['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist4 = list()
for i in range (0,30):
    wslist4.append(pd.DataFrame(pd.DataFrame(Apr19['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist5 = list()
for i in range (0,31):
    wslist5.append(pd.DataFrame(pd.DataFrame(May19['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist6 = list()
for i in range (0,30):
    wslist6.append(pd.DataFrame(pd.DataFrame(Jun19['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist7 = list()
for i in range (0,31):
    wslist7.append(pd.DataFrame(pd.DataFrame(Jul19['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist8 = list()
for i in range (0,31):
    wslist8.append(pd.DataFrame(pd.DataFrame(Aug19['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist9 = list()
for i in range (0,30):
    wslist9.append(pd.DataFrame(pd.DataFrame(Sep19['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist10 = list()
for i in range (0,31):
    wslist10.append(pd.DataFrame(pd.DataFrame(Oct19['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist11 = list()
for i in range (0,30):
    wslist11.append(pd.DataFrame(pd.DataFrame(Nov19['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist12 = list()
for i in range (0,31):
    wslist12.append(pd.DataFrame(pd.DataFrame(Dec19['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
ws2019 = wslist1 + wslist2 + wslist3 + wslist4 + wslist5 + wslist6 + wslist7 + wslist8 + wslist9 + wslist10 + wslist11 + wslist12

# %%
len(ws2019)
# Out:
# 365

# %% [markdown]
# #### ======2020windspeed

# %%
wslist1 = list()
for i in range (0,31):
    wslist1.append(pd.DataFrame(pd.DataFrame(Jan20['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist2 = list()
for i in range (0,29):
    wslist2.append(pd.DataFrame(pd.DataFrame(Feb20['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist3 = list()
for i in range (0,31):
    wslist3.append(pd.DataFrame(pd.DataFrame(Mar20['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist4 = list()
for i in range (0,30):
    wslist4.append(pd.DataFrame(pd.DataFrame(Apr20['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist5 = list()
for i in range (0,31):
    wslist5.append(pd.DataFrame(pd.DataFrame(May20['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist6 = list()
for i in range (0,30):
    wslist6.append(pd.DataFrame(pd.DataFrame(Jun20['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist7 = list()
for i in range (0,31):
    wslist7.append(pd.DataFrame(pd.DataFrame(Jul20['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist8 = list()
for i in range (0,31):
    wslist8.append(pd.DataFrame(pd.DataFrame(Aug20['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist9 = list()
for i in range (0,30):
    wslist9.append(pd.DataFrame(pd.DataFrame(Sep20['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist10 = list()
for i in range (0,31):
    wslist10.append(pd.DataFrame(pd.DataFrame(Oct20['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist11 = list()
for i in range (0,30):
    wslist11.append(pd.DataFrame(pd.DataFrame(Nov20['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
wslist12 = list()
for i in range (0,31):
    wslist12.append(pd.DataFrame(pd.DataFrame(Dec20['data']['weather'])['hourly'][i])['windspeedKmph'])

# %%
ws2020 = wslist1 + wslist2 + wslist3 + wslist4 + wslist5 + wslist6 + wslist7 + wslist8 + wslist9 + wslist10 + wslist11 + wslist12

# %%
len(ws2020)
# Out:
# 366

# %% [markdown]
# #### ======humidity

# %%
hulist1 = list()
for i in range (0,31):
    hulist1.append(pd.DataFrame(pd.DataFrame(Jan19['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist2 = list()
for i in range (0,28):
    hulist2.append(pd.DataFrame(pd.DataFrame(Feb19['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist3 = list()
for i in range (0,31):
    hulist3.append(pd.DataFrame(pd.DataFrame(Mar19['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist4 = list()
for i in range (0,30):
    hulist4.append(pd.DataFrame(pd.DataFrame(Apr19['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist5 = list()
for i in range (0,31):
    hulist5.append(pd.DataFrame(pd.DataFrame(May19['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist6 = list()
for i in range (0,30):
    hulist6.append(pd.DataFrame(pd.DataFrame(Jun19['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist7 = list()
for i in range (0,31):
    hulist7.append(pd.DataFrame(pd.DataFrame(Jul19['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist8 = list()
for i in range (0,31):
    hulist8.append(pd.DataFrame(pd.DataFrame(Aug19['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist9 = list()
for i in range (0,30):
    hulist9.append(pd.DataFrame(pd.DataFrame(Sep19['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist10 = list()
for i in range (0,31):
    hulist10.append(pd.DataFrame(pd.DataFrame(Oct19['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist11 = list()
for i in range (0,30):
    hulist11.append(pd.DataFrame(pd.DataFrame(Nov19['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist12 = list()
for i in range (0,31):
    hulist12.append(pd.DataFrame(pd.DataFrame(Dec19['data']['weather'])['hourly'][i])['humidity'])

# %%
hu2019 = hulist1 + hulist2 + hulist3 + hulist4 + hulist5 + hulist6 + hulist7 + hulist8 + hulist9 + hulist10 + hulist11 + hulist12

# %%
len(hu2019)
# Out:
# 365

# %%
hulist1 = list()
for i in range (0,31):
    hulist1.append(pd.DataFrame(pd.DataFrame(Jan20['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist2 = list()
for i in range (0,29):
    hulist2.append(pd.DataFrame(pd.DataFrame(Feb20['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist3 = list()
for i in range (0,31):
    hulist3.append(pd.DataFrame(pd.DataFrame(Mar20['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist4 = list()
for i in range (0,30):
    hulist4.append(pd.DataFrame(pd.DataFrame(Apr20['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist5 = list()
for i in range (0,31):
    hulist5.append(pd.DataFrame(pd.DataFrame(May20['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist6 = list()
for i in range (0,30):
    hulist6.append(pd.DataFrame(pd.DataFrame(Jun20['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist7 = list()
for i in range (0,31):
    hulist7.append(pd.DataFrame(pd.DataFrame(Jul20['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist8 = list()
for i in range (0,31):
    hulist8.append(pd.DataFrame(pd.DataFrame(Aug20['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist9 = list()
for i in range (0,30):
    hulist9.append(pd.DataFrame(pd.DataFrame(Sep20['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist10 = list()
for i in range (0,31):
    hulist10.append(pd.DataFrame(pd.DataFrame(Oct20['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist11 = list()
for i in range (0,30):
    hulist11.append(pd.DataFrame(pd.DataFrame(Nov20['data']['weather'])['hourly'][i])['humidity'])

# %%
hulist12 = list()
for i in range (0,31):
    hulist12.append(pd.DataFrame(pd.DataFrame(Dec20['data']['weather'])['hourly'][i])['humidity'])

# %%
hu2020 = hulist1 + hulist2 + hulist3 + hulist4 + hulist5 + hulist6 + hulist7 + hulist8 + hulist9 + hulist10 + hulist11 + hulist12

# %%
len(hu2020)
# Out:
# 366

# %% [markdown]
# #### =======Save data to file with date index

# %%
ws2018n = list()
for i in range(0,365):
    ws2018n.append(int(ws2018[i].item()))     #get the item from series, and convert string to integer

# %%
hu2018n = list()
for i in range(0,365):
    hu2018n.append(int(hu2018[i].item()))     #get the item from series, and convert string to integer

# %%
ws2019n = list()
for i in range(0,365):
    ws2019n.append(int(ws2019[i].item()))     #get the item from series, and convert string to integer

# %%
hu2019n = list()
for i in range(0,365):
    hu2019n.append(int(hu2019[i].item()))     #get the item from series, and convert string to integer

# %%
ws2020n = list()
for i in range(0,366):
    ws2020n.append(int(ws2020[i].item()))     #get the item from series, and convert string to integer

# %%
hu2020n = list()
for i in range(0,366):
    hu2020n.append(int(hu2020[i].item()))     #get the item from series, and convert string to integer

# %%
final2018 = pd.DataFrame(
{'WS':ws2018n,
 'HU':hu2018n}
)
final2018['Date'] = pd.date_range(start="2018-01-01",end="2018-12-31")
final2018 = final2018.set_index('Date')

# %%
final2019 = pd.DataFrame(
{'WS':ws2019n,
 'HU':hu2019n}
)
final2019['Date'] = pd.date_range(start="2019-01-01",end="2019-12-31")
final2019 = final2019.set_index('Date')

# %%
final2020 = pd.DataFrame(
{'WS':ws2020n,
 'HU':hu2020n}
)
final2020['Date'] = pd.date_range(start="2020-01-01",end="2020-12-31")
final2020 = final2020.set_index('Date')

# %%
f = final2018.append(final2019)

# %%
f = f.append(final2020)

# %%
f
# Out:
#             WS  HU
# Date
# 2018-01-01  21  74
# 2018-01-02  20  81
# 2018-01-03  34  72
# 2018-01-04  16  86
# 2018-01-05  17  83
# ...         ..  ..
# 2020-12-27  22  76
# 2020-12-28  20  77
# 2020-12-29  18  74
# 2020-12-30  18  76
# 2020-12-31  21  83
#
# [1096 rows x 2 columns]

# %%
f.to_csv('finalweather.csv')
