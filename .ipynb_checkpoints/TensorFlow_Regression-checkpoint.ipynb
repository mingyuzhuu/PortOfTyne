# %%
import tensorflow as tf
import sklearn as sk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import plotly.express as px

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
import os
os.getcwd()
# Out:
# 'E:\\20190923 Newcastle-M.Res\\OneDrive - Newcastle University\\21_22_autumn\\211018\\code'

# %%
df= pd.read_csv('data/finaldata.csv', header = 0, index_col = 0 )

# %%
df.head()
# Out:
#             WindSpeed  Humidity  Tonnes  Energy/kwh
# Date
# 01/01/2018         21        74     NaN      646.92
# 02/01/2018         20        81     NaN     1391.50
# 03/01/2018         34        72     NaN     1660.89
# 04/01/2018         16        86     NaN     1046.34
# 05/01/2018         17        83     NaN     1739.67

# %%
px.scatter_3d(df, x = 'WindSpeed', y = 'Humidity', z = 'Energy/kwh')
# Out:
# <div>                            <div id="e074cdc9-0c1b-4e65-ab47-72006eb80008" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e074cdc9-0c1b-4e65-ab47-72006eb80008")) {                    Plotly.newPlot(                        "e074cdc9-0c1b-4e65-ab47-72006eb80008",                        [{"hovertemplate":"WindSpeed=%{x}<br>Humidity=%{y}<br>Energy/kwh=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[21,20,34,16,17,27,10,18,19,12,13,11,23,26,26,32,33,20,22,16,17,24,27,34,18,13,26,24,28,24,32,34,23,7,12,8,17,16,18,19,21,30,27,26,30,27,23,18,11,7,21,11,12,18,22,18,17,23,32,41,36,23,17,9,17,13,10,13,15,7,13,9,23,33,35,37,35,24,15,21,20,24,6,14,11,19,
# ...

# %%
px.scatter(df, x = 'Tonnes', y = 'Energy/kwh')
# Out:
# <div>                            <div id="9a5129e9-3792-4109-9869-73402473c46b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a5129e9-3792-4109-9869-73402473c46b")) {                    Plotly.newPlot(                        "9a5129e9-3792-4109-9869-73402473c46b",                        [{"hovertemplate":"Tonnes=%{x}<br>Energy/kwh=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nu
# ...

# %%
dataset = np.genfromtxt('data/finaldata.csv', delimiter=',',skip_header = True, usecols=(1,2,3,4))
type(dataset)
# Out:
# numpy.ndarray

# %%
dataset
# Out:
# array([[  21.  ,   74.  ,     nan,  646.92],
#        [  20.  ,   81.  ,     nan, 1391.5 ],
#        [  34.  ,   72.  ,     nan, 1660.89],
#        ...,
#        [  18.  ,   74.  ,     nan, 6115.43],
#        [  18.  ,   76.  ,     nan, 5472.71],
#        [  21.  ,   83.  ,     nan, 3659.57]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(1, input_dim = 1, activation = 'linear'))
model.compile(loss = 'mse', optimizer = 'rmsprop', metrics = ['mse'])

# %%
model.fit(x = dataset[:,2], y = dataset[:, 3], epochs = 256, verbose = 1)
# Out:
# Epoch 1/256
# 35/35 [==============================] - 0s 769us/step - loss: nan - mse: nan
# Epoch 2/256
# 35/35 [==============================] - 0s 697us/step - loss: nan - mse: nan
# Epoch 3/256
# 35/35 [==============================] - 0s 677us/step - loss: nan - mse: nan
# Epoch 4/256
# 35/35 [==============================] - 0s 693us/step - loss: nan - mse: nan
# Epoch 5/256
# 35/35 [==============================] - 0s 709us/step - loss: nan - mse: nan
# Epoch 6/256
# 35/35 [==============================] - 0s 700us/step - loss: nan - mse: nan
# Epoch 7/256
# 35/35 [==============================] - 0s 740us/step - loss: nan - mse: nan
# Epoch 8/256
# 35/35 [==============================] - 0s 717us/step - loss: nan - mse: nan
# Epoch 9/256
# 35/35 [==============================] - 0s 651us/step - loss: nan - mse: nan
# Epoch 10/256
# 35/35 [==============================] - 0s 692us/step - loss: nan - mse: nan
# Epoch 11/256
# ...

# %%
 predictions = model.predict(dataset[:,3])

# %%
 predictions
# Out:
# array([[nan],
#        [nan],
#        [nan],
#        ...,
#        [nan],
#        [nan],
#        [nan]], dtype=float32)

# %%
true_energy = dataset[:,3]

# %%
print(true_energy[:5])
# Out:
# [ 646.92 1391.5  1660.89 1046.34 1739.67]

# %%
print(predictions[:5].T)
# Out:
# [[nan nan nan nan nan]]
